# %% [markdown]
# APIs to be used:
# - Messari - https://messari.io/api/docs
# - Coinpaprika - https://api.coinpaprika.com/ and https://coinpaprika.com/api/ (strength people ID and tags + free api)
# - IBM personality -

# %% [markdown]
# IBM personality Insights:
# https://cloud.ibm.com/docs/services/personality-insights?topic=personality-insights-models#models

# %%
# %%HTML
# Out:
# UsageError: %%HTML is a cell magic, but the cell body is empty.

# %%
import requests
url = 'https://data.messari.io/api/v1/assets'
##payload = {"id":"007fe708","symbol":"zil","name":"Zilliqa"}
data = requests.get(url)
print(data.text[0])
##data.encoding
data.status_code

# %%
import json
import requests
url = 'https://api.github.com/users/willremor/starred'
data = requests.get(url)
package_json = data.json()

#print(len(package_json))
package_str = json.dumps(package_json, indent = 4)
print(package_str)
# Out:
# [
#     {
#         "id": 51025151,
#         "node_id": "MDEwOlJlcG9zaXRvcnk1MTAyNTE1MQ==",
#         "name": "data-tutorials",
#         "full_name": "hortonworks/data-tutorials",
#         "private": false,
#         "owner": {
#             "login": "hortonworks",
#             "id": 898785,
#             "node_id": "MDEyOk9yZ2FuaXphdGlvbjg5ODc4NQ==",
#             "avatar_url": "https://avatars2.githubusercontent.com/u/898785?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/hortonworks",
#             "html_url": "https://github.com/hortonworks",
#             "followers_url": "https://api.github.com/users/hortonworks/followers",
#             "following_url": "https://api.github.com/users/hortonworks/following{/other_user}",
#             "gists_url": "https://api.github.com/users/hortonworks/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/hortonworks/starred{/owner}{/repo}",
# ...

# %%
import json
import requests
url = 'https://api.github.com/users/willremor/starred'
data = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-6be64475ce4c> in <module>
#       3 url = 'https://api.github.com/users/willremor/starred'
#       4 data = requests.get(url)
# ----> 5 data.link()
#
# AttributeError: 'Response' object has no attribute 'link'

# %%
##print(package_json)

#Get first element in list
package_str = json.dumps(package_json, indent = 4)
#package_str = json.dumps(package_json[0], indent = 4)
#print(package_str)

name = package_json['name']
html = package_json['owner']['html_url']
desc = package_json['description']

print(name,html, desc)

# %%
data.text[0:500]
# Out:
# '[{"id":133534163,"node_id":"MDEwOlJlcG9zaXRvcnkxMzM1MzQxNjM=","name":"prettier-plugin-solidity","full_name":"prettier-solidity/prettier-plugin-solidity","private":false,"owner":{"login":"prettier-solidity","id":40924486,"node_id":"MDEyOk9yZ2FuaXphdGlvbjQwOTI0NDg2","avatar_url":"https://avatars3.githubusercontent.com/u/40924486?v=4","gravatar_id":"","url":"https://api.github.com/users/prettier-solidity","html_url":"https://github.com/prettier-solidity","followers_url":"https://api.github.com/user'

# %%
from six.moves import urllib
url = "https://data.messari.io/api/v1/assets"
print(urllib.request.urlopen(url).read())
# Out:
# b'{"status":{"elapsed":"4","timestamp":"2019-04-03T19:06:29.089532859Z"},"data":[{"id":"000b948f","symbol":"daxx","name":"DaxxCoin"},{"id":"00305212","symbol":"bon","name":"Bonpay"},{"id":"003cf664","symbol":"sfe","name":"SafeCoin"},{"id":"00509790","symbol":"bxt","name":"BitTokens"},{"id":"005a55a6","symbol":"storm","name":"Storm"},{"id":"0067c762","symbol":"al","name":"Artificial Intelligence"},{"id":"007fe708","symbol":"zil","name":"Zilliqa"},{"id":"00963575","symbol":"tit","name":"Titcoin"},{"id":"00a2ec83","symbol":"eot","name":"EOT Token"},{"id":"00aa12c6","symbol":"mtl","name":"Metal"},{"id":"00af9860","symbol":"spch","name":"SpaceChain"},{"id":"00b04077","symbol":"dot","name":"Dotcoin"},{"id":"00c5e30c","symbol":"nvcet","name":"NVCET"},{"id":"00cb0486","symbol":"avt","name":"Aventus"},{"id":"00cc2ec0","symbol":"cny","name":"Chinese Yuan"},{"id":"00f35d1d","symbol":"skoin","name":"Skoincoin"},{"id":"00f4f915","symbol":"xrl","name":"Rialto"},{"id":"00f9be9f","symbol":"xvc","nam
# ...

# %%
import requests
url = 'https://data.messari.io/api/v1/assets'
##payload = {"id":"007fe708","symbol":"zil","name":"Zilliqa"}
data = requests.get(url)
print(data.text[0])
##data.encoding
data.status_code

# %%
from six.moves import urllib
url = "https://data.messari.io/api/v1/markets"
print(urllib.request.urlopen(url).read())
# Out:
# b'{"status":{"elapsed":"6","timestamp":"2019-04-03T19:07:34.092909636Z"},"data":[{"id":"0019b21e","exchange":"bitstamp","base":"btc","quote":"usd","pair":"btc-usd"},{"id":"0020ab7f","exchange":"binance","base":"eth","quote":"btc","pair":"eth-btc"},{"id":"0024583a","exchange":"huobi","base":"zrx","quote":"btc","pair":"zrx-btc"},{"id":"00249e4b","exchange":"yobit","base":"argus","quote":"btc","pair":"argus-btc"},{"id":"0025aaac","exchange":"hitbtc","base":"hand","quote":"eth","pair":"hand-eth"},{"id":"003fd80b","exchange":"bittrex","base":"rfr","quote":"btc","pair":"rfr-btc"},{"id":"00600064","exchange":"hitbtc","base":"banca","quote":"eth","pair":"banca-eth"},{"id":"006a4794","exchange":"yobit","base":"xmine","quote":"btc","pair":"xmine-btc"},{"id":"006a8e84","exchange":"hitbtc","base":"tvi","quote":"btc","pair":"tvi-btc"},{"id":"006ac623","exchange":"bitfinex","base":"bci","quote":"usd","pair":"bci-usd"},{"id":"007c8c60","exchange":"yobit","base":"pie","quote":"btc","pair":"pie-btc"}
# ...

# %%
from six.moves import urllib
url = "https://data.messari.io/api/v1/assets/ada/profile"
print(urllib.request.urlopen(url).read())
# Out:
# b'{"status":{"elapsed":"0","timestamp":"2019-04-03T19:24:42.707248062Z"},"data":{"id":"362f0140","symbol":"ada","name":"Cardano","tagline":"Modular general purpose blockchain platform","overview":"Cardano is a smart-contract based platform that aims to provide multiple features through layered design and modularity. ","background":"Cardano aims to facilitate a wide set of features including smart contracts, decentralized applications, side chains, and multi-party computation. The project was created by the blockchain development firm Input Output Hong Kong (IOHK) and is led by Charles Hoskinson who is a co-founder of BitShares and Ethereum.\\n\\nThe team aims to address three main areas of existing blockchain technology. First, historically the most successful protocols have used a layered design (e.g., TCP/IP) and cryptocurrencies may benefit from the same principle of layering. Second, Cardano aims to accommodate future soft and hard forks, which is important for making future upda
# ...

# %%
from six.moves import urllib
url = "https://data.messari.io/api/v1/assets/myb/metrics"
print(urllib.request.urlopen(url).read())
# Out:
# b'{"status":{"elapsed":"0","timestamp":"2019-04-03T19:17:17.364749023Z"},"data":{"id":"49796395","symbol":"myb","name":"MyBit Token","market_data":{"price_usd":0.007836354590630923,"price_btc":0.000001518053602187941,"volume_last_24_hours":139.72220235094935,"real_volume_last_24_hours":null,"volume_last_24_hours_overstatement_multiple":null,"percent_change_usd_last_24_hours":null,"percent_change_btc_last_24_hours":-8.244597803032253},"marketcap":{"current_marketcap_usd":1197413.7005595542,"y_2050_marketcap_usd":null,"y_plus10_marketcap_usd":null,"liquid_marketcap_usd":null},"supply":{"y_2050":null,"y_plus10":null,"liquid":null,"circulating":152802388.75244,"y_2050_issued_percent":null,"annual_inflation_percent":null,"y_plus10_issued_percent":null},"blockchain_stats_24_hours":{"transaction_volume":null,"adjusted_transaction_volume":null,"nvt":null,"adjusted_nvt":null,"sum_of_fees":null,"median_tx_value":null,"median_tx_fee":null,"count_of_active_addresses":null,"count_of_tx":null,"cou
# ...

# %% [markdown]
# **News all projects. Lastest 50 articles.**

# %%
from six.moves import urllib
url = "https://data.messari.io/api/v1/news"
print(urllib.request.urlopen(url).read())
# Out:
# b'{"status":{"elapsed":"0","timestamp":"2019-04-03T19:20:25.638614627Z"},"data":[{"id":"61b99544-6a33-4cc2-b480-70ea47a66f20","title":"\xf0\x9f\x92\xb9 Jamaica Stock Exchange plans to pilot Bitcoin and Ether trading ","content":"The Jamaica Stock Exchange  is preparing to offer a trial period for trading Bitcoin  and Ether  with help from Canadian fintech firm Blockstation. The two companies announced today that they have agreed to collaborate on enabling live trading of digital assets including security tokens in a \xe2\x80\x9cregulated and secured\xe2\x80\x9d environment. This effort is the second stage of the pilot effort. For the first phase, the JSE and Blockstation trialed live crypto trading in January 2019 for 60 days that saw participation from regulated broker-dealers, market makers and the Jamaica Central Securities Depository.","references":[{"name":"Coin Desk","url":"https://www.coindesk.com/jamaica-stock-exchange-to-pilot-bitcoin-and-ether-trading"}],"reference_title":"
# ...

# %% [markdown]
# **News by token project. Lastest 50 articles.**

# %%
# https://data.messari.io/api/v1/news/{symbol}
from six.moves import urllib
url = "https://data.messari.io/api/v1/news/eth"
print(urllib.request.urlopen(url).read())
# Out:
# b'{"status":{"elapsed":"0","timestamp":"2019-04-03T19:27:43.506226867Z"},"data":[{"id":"61b99544-6a33-4cc2-b480-70ea47a66f20","title":"\xf0\x9f\x92\xb9 Jamaica Stock Exchange plans to pilot Bitcoin and Ether trading ","content":"The Jamaica Stock Exchange  is preparing to offer a trial period for trading Bitcoin  and Ether  with help from Canadian fintech firm Blockstation. The two companies announced today that they have agreed to collaborate on enabling live trading of digital assets including security tokens in a \xe2\x80\x9cregulated and secured\xe2\x80\x9d environment. This effort is the second stage of the pilot effort. For the first phase, the JSE and Blockstation trialed live crypto trading in January 2019 for 60 days that saw participation from regulated broker-dealers, market makers and the Jamaica Central Securities Depository.","references":[{"name":"Coin Desk","url":"https://www.coindesk.com/jamaica-stock-exchange-to-pilot-bitcoin-and-ether-trading"}],"reference_title":"
# ...
